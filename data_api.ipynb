# %%
import pandas as pd
import requests

# %%
# url = "https://api.rentcast.io/v1/properties?city=Los%20Angeles&state=CA&limit=500&includeTotalCount=true"

# headers = {
#     "accept": "application/json",
#     "X-Api-Key": "3d2409857e9f41339e07931b882ccc2a"
# }

# response = requests.get(url, headers=headers)

# %%
raw_data = response.json()

# %%
raw_data
# Out:
# [{'id': '1824-W-69th-St,-Los-Angeles,-CA-90047',
#   'formattedAddress': '1824 W 69th St, Los Angeles, CA 90047',
#   'addressLine1': '1824 W 69th St',
#   'addressLine2': None,
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'stateFips': '06',
#   'zipCode': '90047',
#   'county': 'Los Angeles',
#   'countyFips': '037',
#   'latitude': 33.976738,
#   'longitude': -118.309878,
#   'propertyType': 'Single Family',
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'squareFootage': 1998,
#   'lotSize': 5590,
#   'yearBuilt': 1932,
#   'assessorID': '6016-025-024',
#   'legalDescription': 'TRACT NO 6279 LOT 213',
#   'subdivision': '6279',
#   'zoning': 'LAR1',
#   'features': {'architectureType': 'Spanish',
#    'floorCount': 1,
#    'garage': True,
#    'garageSpaces': 1,
#    'garageType': 'Garage',
#    'heating': True,
#    'heatingType': 'Floor / Wall',
#    'roomCount': 8,
#    'unitCount': 1},
#   'taxAssessments': {'2019': {'year': 2019,
#     'value': 57744,
#     'land': 24147,
# ...

# %%
df = pd.DataFrame(raw_data)

# %%
df["taxAssessments"].isnull().sum()
# Out:
# 460

# %%
df_temp = df.dropna()

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 325 to 459
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7 non-null      object
#  1   formattedAddress  7 non-null      object
#  2   addressLine1      7 non-null      object
#  3   addressLine2      7 non-null      object
#  4   city              7 non-null      object
#  5   state             7 non-null      object
#  6   stateFips         7 non-null      object
#  7   zipCode           7 non-null      object
#  8   county            7 non-null      object
#  9   countyFips        7 non-null      object
#  10  latitude          7 non-null      float64
#  11  longitude         7 non-null      float64
#  12  propertyType      7 non-null      object
#  13  bedrooms          7 non-null      float64
#  14  bathrooms         7 non-null      float64
#  15  squareFootage     7 non-null      float64
# ...

# %%
df.to_csv('date1.csv', index=False)
